# %% [markdown]
# Titanic

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
dataset_path = 'titanic_modified_dataset.csv'
df = pd.read_csv(dataset_path, index_col='PassengerId')
df.head()
# Out:
#              Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Title  \
# PassengerId
# 1                 3    0  22.0      1      0   7.2500         0      0
# 2                 1    1  38.0      1      0  71.2833         1      1
# 3                 3    1  26.0      0      0   7.9250         0      2
# 4                 1    1  35.0      1      0  53.1000         0      1
# 5                 3    0  35.0      0      0   8.0500         0      0
#
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0

# %%
dataset_arr = df.to_numpy().astype(np.float64)
X, y = dataset_arr[:, :-1], dataset_arr[:, -1]

# %%
intercept = np.ones((X.shape[0], 1))
X_b = np.concatenate((intercept, X), axis=1)

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X_b, y,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %%
def sigmol(z):
    return 1 / (1 + np.exp(-z))

def predict(X, theta):
    dot_product = np.dot(X, theta)
    y_hat = sigmol(dot_product)
    return y_hat

def compute_loss(y_hat, y):
    y_hat = np.clip(
        y_hat, 1e-7, 1 - 1e-7
    )
    return (
        -y * \
        np.log(y_hat) - (1 - y) * \
        np.log(1 - y_hat)
    ).mean()

def compute_gradien(X, y, y_hat):
    return np.dot(
        X.T, (y_hat - y)
    ) / y.size

def update_theta(theta, gradien, lr):
    return theta - gradien*lr

def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta).round()
    acc = (y_hat == y).mean()
    return acc

# %%
lr = 0.01
epochs = 100
batch_size = 16

np.random.seed(random_state)
theta = np.random.uniform(
    size = X_train.shape[1]
)

# %%
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
    train_batch_losses = []
    train_batch_accs = []
    val_batch_losses = []
    val_batch_accs = []

    for i in range(0, X_train.shape[0], batch_size):
        X_i = X_train[i:i+batch_size]
        y_i = y_train[i:i+batch_size]

        y_hat = predict(X_i, theta)

        train_loss = compute_loss(y_hat, y_i)
        gradient = compute_gradien(X_i, y_i, y_hat)
        theta = update_theta(theta, gradient, lr)

        train_batch_losses.append(train_loss)

        train_acc = compute_accuracy(X_train, y_train, theta)
        train_batch_accs.append(train_acc)

        y_val_hat = predict(X_val, theta)
        val_loss = compute_loss(y_val_hat, y_val)
        val_batch_losses.append(val_loss)

        val_acc = compute_accuracy(X_val, y_val, theta)
        val_batch_accs.append(val_acc)

    train_batch_loss = sum(train_batch_losses) / len(train_batch_losses)
    val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
    train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
    val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

    train_losses.append(train_batch_loss)
    val_losses.append(val_batch_loss)
    train_accs.append(train_batch_acc)
    val_accs.append(val_batch_acc)

    print(f'\nEPOCHS {epoch + 1}:\tTraining loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:.3f}')
# Out:
# EPOCHS 1:	Training loss: 0.701	Validation loss: 0.599
#
# EPOCHS 2:	Training loss: 0.665	Validation loss: 0.581
#
# EPOCHS 3:	Training loss: 0.634	Validation loss: 0.566
#
# EPOCHS 4:	Training loss: 0.607	Validation loss: 0.554
#
# EPOCHS 5:	Training loss: 0.584	Validation loss: 0.544
#
# EPOCHS 6:	Training loss: 0.563	Validation loss: 0.536
#
# EPOCHS 7:	Training loss: 0.546	Validation loss: 0.530
#
# EPOCHS 8:	Training loss: 0.531	Validation loss: 0.524
#
# EPOCHS 9:	Training loss: 0.518	Validation loss: 0.520
#
# EPOCHS 10:	Training loss: 0.507	Validation loss: 0.517
#
# EPOCHS 11:	Training loss: 0.497	Validation loss: 0.515
#
# EPOCHS 12:	Training loss: 0.489	Validation loss: 0.513
#
# EPOCHS 13:	Training loss: 0.482	Validation loss: 0.512
#
# EPOCHS 14:	Training loss: 0.475	Validation loss: 0.511
#
# EPOCHS 15:	Training loss: 0.470	Validation loss: 0.510
#
# EPOCHS 16:	Training loss: 0.465	Validation loss: 0.510
#
# EPOCHS 17:	Training loss: 0.461	Validation loss: 0.510
#
# EPOCHS 18:	Training loss: 0.457	Validation loss: 0.510
#
# EPOCHS 19:	Training loss: 0.454	Validation loss: 0.510
#
# EPOCHS 20:	Training loss: 0.451	Validation loss: 0.510
#
# EPOCHS 21:	Training loss: 0.448	Validation loss: 0.510
#
# EPOCHS 22:	Training loss: 0.446	Validation loss: 0.511
#
# EPOCHS 23:	Training loss: 0.443	Validation loss: 0.511
#
# EPOCHS 24:	Training loss: 0.441	Validation loss: 0.512
#
# EPOCHS 25:	Training loss: 0.440	Validation loss: 0.512
#
# EPOCHS 26:	Training loss: 0.438	Validation loss: 0.513
#
# EPOCHS 27:	Training loss: 0.437	Validation loss: 0.513
#
# EPOCHS 28:	Training loss: 0.435	Validation loss: 0.514
#
# EPOCHS 29:	Training loss: 0.434	Validation loss: 0.515
#
# EPOCHS 30:	Training loss: 0.433	Validation loss: 0.515
#
# EPOCHS 31:	Training loss: 0.432	Validation loss: 0.516
#
# EPOCHS 32:	Training loss: 0.431	Validation loss: 0.516
#
# EPOCHS 33:	Training loss: 0.430	Validation loss: 0.517
#
# EPOCHS 34:	Training loss: 0.429	Validation loss: 0.518
#
# EPOCHS 35:	Training loss: 0.429	Validation loss: 0.518
#
# EPOCHS 36:	Training loss: 0.428	Validation loss: 0.519
#
# EPOCHS 37:	Training loss: 0.427	Validation loss: 0.519
#
# EPOCHS 38:	Training loss: 0.427	Validation loss: 0.520
#
# EPOCHS 39:	Training loss: 0.426	Validation loss: 0.520
#
# EPOCHS 40:	Training loss: 0.426	Validation loss: 0.521
#
# EPOCHS 41:	Training loss: 0.425	Validation loss: 0.521
#
# EPOCHS 42:	Training loss: 0.425	Validation loss: 0.522
#
# EPOCHS 43:	Training loss: 0.425	Validation loss: 0.522
#
# EPOCHS 44:	Training loss: 0.424	Validation loss: 0.523
#
# EPOCHS 45:	Training loss: 0.424	Validation loss: 0.523
#
# EPOCHS 46:	Training loss: 0.424	Validation loss: 0.524
#
# EPOCHS 47:	Training loss: 0.423	Validation loss: 0.524
#
# EPOCHS 48:	Training loss: 0.423	Validation loss: 0.524
#
# EPOCHS 49:	Training loss: 0.423	Validation loss: 0.525
#
# EPOCHS 50:	Training loss: 0.422	Validation loss: 0.525
#
# EPOCHS 51:	Training loss: 0.422	Validation loss: 0.526
#
# EPOCHS 52:	Training loss: 0.422	Validation loss: 0.526
#
# EPOCHS 53:	Training loss: 0.422	Validation loss: 0.526
#
# EPOCHS 54:	Training loss: 0.422	Validation loss: 0.527
#
# EPOCHS 55:	Training loss: 0.421	Validation loss: 0.527
#
# EPOCHS 56:	Training loss: 0.421	Validation loss: 0.527
#
# EPOCHS 57:	Training loss: 0.421	Validation loss: 0.528
#
# EPOCHS 58:	Training loss: 0.421	Validation loss: 0.528
#
# EPOCHS 59:	Training loss: 0.421	Validation loss: 0.528
#
# EPOCHS 60:	Training loss: 0.421	Validation loss: 0.529
#
# EPOCHS 61:	Training loss: 0.420	Validation loss: 0.529
#
# EPOCHS 62:	Training loss: 0.420	Validation loss: 0.529
#
# EPOCHS 63:	Training loss: 0.420	Validation loss: 0.529
#
# EPOCHS 64:	Training loss: 0.420	Validation loss: 0.530
#
# EPOCHS 65:	Training loss: 0.420	Validation loss: 0.530
#
# EPOCHS 66:	Training loss: 0.420	Validation loss: 0.530
#
# EPOCHS 67:	Training loss: 0.420	Validation loss: 0.530
#
# EPOCHS 68:	Training loss: 0.420	Validation loss: 0.531
#
# EPOCHS 69:	Training loss: 0.420	Validation loss: 0.531
#
# EPOCHS 70:	Training loss: 0.419	Validation loss: 0.531
#
# EPOCHS 71:	Training loss: 0.419	Validation loss: 0.531
#
# EPOCHS 72:	Training loss: 0.419	Validation loss: 0.532
#
# EPOCHS 73:	Training loss: 0.419	Validation loss: 0.532
#
# EPOCHS 74:	Training loss: 0.419	Validation loss: 0.532
#
# EPOCHS 75:	Training loss: 0.419	Validation loss: 0.532
#
# EPOCHS 76:	Training loss: 0.419	Validation loss: 0.532
#
# EPOCHS 77:	Training loss: 0.419	Validation loss: 0.533
#
# EPOCHS 78:	Training loss: 0.419	Validation loss: 0.533
#
# EPOCHS 79:	Training loss: 0.419	Validation loss: 0.533
#
# EPOCHS 80:	Training loss: 0.419	Validation loss: 0.533
#
# EPOCHS 81:	Training loss: 0.419	Validation loss: 0.533
#
# EPOCHS 82:	Training loss: 0.419	Validation loss: 0.534
#
# EPOCHS 83:	Training loss: 0.419	Validation loss: 0.534
#
# EPOCHS 84:	Training loss: 0.419	Validation loss: 0.534
#
# EPOCHS 85:	Training loss: 0.419	Validation loss: 0.534
#
# EPOCHS 86:	Training loss: 0.419	Validation loss: 0.534
#
# EPOCHS 87:	Training loss: 0.419	Validation loss: 0.534
#
# EPOCHS 88:	Training loss: 0.418	Validation loss: 0.534
#
# EPOCHS 89:	Training loss: 0.418	Validation loss: 0.535
#
# EPOCHS 90:	Training loss: 0.418	Validation loss: 0.535
#
# EPOCHS 91:	Training loss: 0.418	Validation loss: 0.535
#
# EPOCHS 92:	Training loss: 0.418	Validation loss: 0.535
#
# EPOCHS 93:	Training loss: 0.418	Validation loss: 0.535
#
# EPOCHS 94:	Training loss: 0.418	Validation loss: 0.535
#
# EPOCHS 95:	Training loss: 0.418	Validation loss: 0.535
#
# EPOCHS 96:	Training loss: 0.418	Validation loss: 0.536
#
# EPOCHS 97:	Training loss: 0.418	Validation loss: 0.536
#
# EPOCHS 98:	Training loss: 0.418	Validation loss: 0.536
#
# EPOCHS 99:	Training loss: 0.418	Validation loss: 0.536
#
# EPOCHS 100:	Training loss: 0.418	Validation loss: 0.536

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, 'orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %%
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy(X_test, y_test, theta)
print('Evaluation on validation and test set')
print(f'Accuracy: {val_set_acc}')
print(f'Accuracy: {test_set_acc}')
# Out:
# Evaluation on validation and test set
# Accuracy: 0.75
# Accuracy: 0.7959183673469388

# %% [markdown]
# Sentiment

# %%
import pandas as pd
import numpy as np

import re
import nltk
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from nltk.tokenize import TweetTokenizer
from collections import defaultdict

# %%
dataset_path = 'sentiment_analysis.csv'
df = pd.read_csv(
    dataset_path,
    index_col='id'
)
df.head()
# Out:
#     label                                              tweet
# id
# 1       0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 2       0  Finally a transparant silicon case ^^ Thanks t...
# 3       0  We love this! Would you go? #talk #makememorie...
# 4       0  I'm wired I know I'm George I was made that wa...
# 5       1  What amazing service! Apple won't even talk to...

# %%
def text_normalize(text):
    text = re.sub(r'^RT[\s]+', '', text)
    
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)
    
    text = re.sub(r'#', '', text)
    
    text = re.sub(r'[^\w\s]', '', text)
    
    tokenizer = TweetTokenizer(
        preserve_case=False,
        strip_handles=True,
        reduce_len=True
    )
    text_tokens = tokenizer.tokenize(text)
    return text_tokens

def get_freqs(df):
    freqs = defaultdict(lambda: 0)
    for idx, row in df.iterrows():
        tweet = row['tweet']
        label = row['label']
        
        tokens = text_normalize(tweet)
        for token in tokens:
            pair = (token, label)
            freqs[pair] += 1
    return freqs

def get_feature(text, freqs):
    tokens = text_normalize(text)
    X = np.zeros(3)
    X[0] = 1
    for token in tokens:
        X[1] += freqs[(token, 0)]
        X[2] += freqs[(token, 1)]
    return X

# %%
X = []
y = []

freqs = get_freqs(df)
for idx, row in df.iterrows():
    tweet = row['tweet']
    label = row['label']
    
    X_i = get_feature(tweet, freqs)
    
    X.append(X_i)
    y.append(label)

X = np.array(X)
y = np.array(y)

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %%
def sigmol(z):
    return 1 / (1 + np.exp(-z))

def predict(X, theta):
    dot_product = np.dot(X, theta)
    y_hat = sigmol(dot_product)
    return y_hat

def compute_loss(y_hat, y):
    y_hat = np.clip(
        y_hat, 1e-7, 1 - 1e-7
    )
    return (
        -y * \
        np.log(y_hat) - (1 - y) * \
        np.log(1 - y_hat)
    ).mean()

def compute_gradien(X, y, y_hat):
    return np.dot(
        X.T, (y_hat - y)
    ) / y.size

def update_theta(theta, gradien, lr):
    return theta - gradien*lr

def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta).round()
    acc = (y_hat == y).mean()
    return acc

# %%
lr = 0.01
epochs = 200
batch_size = 128

np.random.seed(random_state)
theta = np.random.uniform(
    size=X_train.shape[1]
)

# %%
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
    train_batch_losses = []
    train_batch_accs = []
    val_batch_losses = []
    val_batch_accs = []

    for i in range(0, X_train.shape[0], batch_size):
        X_i = X_train[i:i+batch_size]
        y_i = y_train[i:i+batch_size]

        y_hat = predict(X_i, theta)

        train_loss = compute_loss(y_hat, y_i)
        gradient = compute_gradien(X_i, y_i, y_hat)
        theta = update_theta(theta, gradient, lr)

        train_batch_losses.append(train_loss)

        train_acc = compute_accuracy(X_train, y_train, theta)
        train_batch_accs.append(train_acc)

        y_val_hat = predict(X_val, theta)
        val_loss = compute_loss(y_val_hat, y_val)
        val_batch_losses.append(val_loss)

        val_acc = compute_accuracy(X_val, y_val, theta)
        val_batch_accs.append(val_acc)

    train_batch_loss = sum(train_batch_losses) / len(train_batch_losses)
    val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
    train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
    val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

    train_losses.append(train_batch_loss)
    val_losses.append(val_batch_loss)
    train_accs.append(train_batch_acc)
    val_accs.append(val_batch_acc)

    print(f'\nEPOCHS {epoch + 1}:\tTraining loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:.3f}')
# Out:
# EPOCHS 1:	Training loss: 0.707	Validation loss: 0.704
#
# EPOCHS 2:	Training loss: 0.661	Validation loss: 0.659
#
# EPOCHS 3:	Training loss: 0.624	Validation loss: 0.622
#
# EPOCHS 4:	Training loss: 0.594	Validation loss: 0.591
#
# EPOCHS 5:	Training loss: 0.569	Validation loss: 0.566
#
# EPOCHS 6:	Training loss: 0.548	Validation loss: 0.546
#
# EPOCHS 7:	Training loss: 0.531	Validation loss: 0.528
#
# EPOCHS 8:	Training loss: 0.516	Validation loss: 0.514
#
# EPOCHS 9:	Training loss: 0.504	Validation loss: 0.502
#
# EPOCHS 10:	Training loss: 0.494	Validation loss: 0.491
#
# EPOCHS 11:	Training loss: 0.485	Validation loss: 0.483
#
# EPOCHS 12:	Training loss: 0.477	Validation loss: 0.475
#
# EPOCHS 13:	Training loss: 0.471	Validation loss: 0.468
#
# EPOCHS 14:	Training loss: 0.465	Validation loss: 0.463
#
# EPOCHS 15:	Training loss: 0.460	Validation loss: 0.457
#
# EPOCHS 16:	Training loss: 0.456	Validation loss: 0.453
#
# EPOCHS 17:	Training loss: 0.452	Validation loss: 0.449
#
# EPOCHS 18:	Training loss: 0.448	Validation loss: 0.445
#
# EPOCHS 19:	Training loss: 0.445	Validation loss: 0.442
#
# EPOCHS 20:	Training loss: 0.442	Validation loss: 0.439
#
# EPOCHS 21:	Training loss: 0.440	Validation loss: 0.437
#
# EPOCHS 22:	Training loss: 0.437	Validation loss: 0.434
#
# EPOCHS 23:	Training loss: 0.435	Validation loss: 0.432
#
# EPOCHS 24:	Training loss: 0.433	Validation loss: 0.430
#
# EPOCHS 25:	Training loss: 0.431	Validation loss: 0.428
#
# EPOCHS 26:	Training loss: 0.430	Validation loss: 0.426
#
# EPOCHS 27:	Training loss: 0.428	Validation loss: 0.425
#
# EPOCHS 28:	Training loss: 0.427	Validation loss: 0.423
#
# EPOCHS 29:	Training loss: 0.425	Validation loss: 0.422
#
# EPOCHS 30:	Training loss: 0.424	Validation loss: 0.420
#
# EPOCHS 31:	Training loss: 0.423	Validation loss: 0.419
#
# EPOCHS 32:	Training loss: 0.421	Validation loss: 0.418
#
# EPOCHS 33:	Training loss: 0.420	Validation loss: 0.417
#
# EPOCHS 34:	Training loss: 0.419	Validation loss: 0.416
#
# EPOCHS 35:	Training loss: 0.418	Validation loss: 0.415
#
# EPOCHS 36:	Training loss: 0.417	Validation loss: 0.414
#
# EPOCHS 37:	Training loss: 0.416	Validation loss: 0.413
#
# EPOCHS 38:	Training loss: 0.415	Validation loss: 0.412
#
# EPOCHS 39:	Training loss: 0.414	Validation loss: 0.411
#
# EPOCHS 40:	Training loss: 0.414	Validation loss: 0.410
#
# EPOCHS 41:	Training loss: 0.413	Validation loss: 0.409
#
# EPOCHS 42:	Training loss: 0.412	Validation loss: 0.408
#
# EPOCHS 43:	Training loss: 0.411	Validation loss: 0.408
#
# EPOCHS 44:	Training loss: 0.411	Validation loss: 0.407
#
# EPOCHS 45:	Training loss: 0.410	Validation loss: 0.406
#
# EPOCHS 46:	Training loss: 0.409	Validation loss: 0.405
#
# EPOCHS 47:	Training loss: 0.409	Validation loss: 0.405
#
# EPOCHS 48:	Training loss: 0.408	Validation loss: 0.404
#
# EPOCHS 49:	Training loss: 0.407	Validation loss: 0.403
#
# EPOCHS 50:	Training loss: 0.407	Validation loss: 0.403
#
# EPOCHS 51:	Training loss: 0.406	Validation loss: 0.402
#
# EPOCHS 52:	Training loss: 0.406	Validation loss: 0.402
#
# EPOCHS 53:	Training loss: 0.405	Validation loss: 0.401
#
# EPOCHS 54:	Training loss: 0.404	Validation loss: 0.400
#
# EPOCHS 55:	Training loss: 0.404	Validation loss: 0.400
#
# EPOCHS 56:	Training loss: 0.403	Validation loss: 0.399
#
# EPOCHS 57:	Training loss: 0.403	Validation loss: 0.399
#
# EPOCHS 58:	Training loss: 0.402	Validation loss: 0.398
#
# EPOCHS 59:	Training loss: 0.402	Validation loss: 0.398
#
# EPOCHS 60:	Training loss: 0.401	Validation loss: 0.397
#
# EPOCHS 61:	Training loss: 0.401	Validation loss: 0.397
#
# EPOCHS 62:	Training loss: 0.401	Validation loss: 0.396
#
# EPOCHS 63:	Training loss: 0.400	Validation loss: 0.396
#
# EPOCHS 64:	Training loss: 0.400	Validation loss: 0.396
#
# EPOCHS 65:	Training loss: 0.399	Validation loss: 0.395
#
# EPOCHS 66:	Training loss: 0.399	Validation loss: 0.395
#
# EPOCHS 67:	Training loss: 0.399	Validation loss: 0.394
#
# EPOCHS 68:	Training loss: 0.398	Validation loss: 0.394
#
# EPOCHS 69:	Training loss: 0.398	Validation loss: 0.394
#
# EPOCHS 70:	Training loss: 0.397	Validation loss: 0.393
#
# EPOCHS 71:	Training loss: 0.397	Validation loss: 0.393
#
# EPOCHS 72:	Training loss: 0.397	Validation loss: 0.392
#
# EPOCHS 73:	Training loss: 0.396	Validation loss: 0.392
#
# EPOCHS 74:	Training loss: 0.396	Validation loss: 0.392
#
# EPOCHS 75:	Training loss: 0.396	Validation loss: 0.391
#
# EPOCHS 76:	Training loss: 0.395	Validation loss: 0.391
#
# EPOCHS 77:	Training loss: 0.395	Validation loss: 0.391
#
# EPOCHS 78:	Training loss: 0.395	Validation loss: 0.390
#
# EPOCHS 79:	Training loss: 0.394	Validation loss: 0.390
#
# EPOCHS 80:	Training loss: 0.394	Validation loss: 0.390
#
# EPOCHS 81:	Training loss: 0.394	Validation loss: 0.389
#
# EPOCHS 82:	Training loss: 0.394	Validation loss: 0.389
#
# EPOCHS 83:	Training loss: 0.393	Validation loss: 0.389
#
# EPOCHS 84:	Training loss: 0.393	Validation loss: 0.389
#
# EPOCHS 85:	Training loss: 0.393	Validation loss: 0.388
#
# EPOCHS 86:	Training loss: 0.392	Validation loss: 0.388
#
# EPOCHS 87:	Training loss: 0.392	Validation loss: 0.388
#
# EPOCHS 88:	Training loss: 0.392	Validation loss: 0.388
#
# EPOCHS 89:	Training loss: 0.392	Validation loss: 0.387
#
# EPOCHS 90:	Training loss: 0.391	Validation loss: 0.387
#
# EPOCHS 91:	Training loss: 0.391	Validation loss: 0.387
#
# EPOCHS 92:	Training loss: 0.391	Validation loss: 0.387
#
# EPOCHS 93:	Training loss: 0.391	Validation loss: 0.386
#
# EPOCHS 94:	Training loss: 0.391	Validation loss: 0.386
#
# EPOCHS 95:	Training loss: 0.390	Validation loss: 0.386
#
# EPOCHS 96:	Training loss: 0.390	Validation loss: 0.386
#
# EPOCHS 97:	Training loss: 0.390	Validation loss: 0.385
#
# EPOCHS 98:	Training loss: 0.390	Validation loss: 0.385
#
# EPOCHS 99:	Training loss: 0.390	Validation loss: 0.385
#
# EPOCHS 100:	Training loss: 0.389	Validation loss: 0.385
#
# EPOCHS 101:	Training loss: 0.389	Validation loss: 0.385
#
# EPOCHS 102:	Training loss: 0.389	Validation loss: 0.384
#
# EPOCHS 103:	Training loss: 0.389	Validation loss: 0.384
#
# EPOCHS 104:	Training loss: 0.389	Validation loss: 0.384
#
# EPOCHS 105:	Training loss: 0.388	Validation loss: 0.384
#
# EPOCHS 106:	Training loss: 0.388	Validation loss: 0.384
#
# EPOCHS 107:	Training loss: 0.388	Validation loss: 0.383
#
# EPOCHS 108:	Training loss: 0.388	Validation loss: 0.383
#
# EPOCHS 109:	Training loss: 0.388	Validation loss: 0.383
#
# EPOCHS 110:	Training loss: 0.388	Validation loss: 0.383
#
# EPOCHS 111:	Training loss: 0.387	Validation loss: 0.383
#
# EPOCHS 112:	Training loss: 0.387	Validation loss: 0.382
#
# EPOCHS 113:	Training loss: 0.387	Validation loss: 0.382
#
# EPOCHS 114:	Training loss: 0.387	Validation loss: 0.382
#
# EPOCHS 115:	Training loss: 0.387	Validation loss: 0.382
#
# EPOCHS 116:	Training loss: 0.387	Validation loss: 0.382
#
# EPOCHS 117:	Training loss: 0.386	Validation loss: 0.382
#
# EPOCHS 118:	Training loss: 0.386	Validation loss: 0.382
#
# EPOCHS 119:	Training loss: 0.386	Validation loss: 0.381
#
# EPOCHS 120:	Training loss: 0.386	Validation loss: 0.381
#
# EPOCHS 121:	Training loss: 0.386	Validation loss: 0.381
#
# EPOCHS 122:	Training loss: 0.386	Validation loss: 0.381
#
# EPOCHS 123:	Training loss: 0.386	Validation loss: 0.381
#
# EPOCHS 124:	Training loss: 0.386	Validation loss: 0.381
#
# EPOCHS 125:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCHS 126:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCHS 127:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCHS 128:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCHS 129:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCHS 130:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCHS 131:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCHS 132:	Training loss: 0.385	Validation loss: 0.380
#
# EPOCHS 133:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCHS 134:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCHS 135:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCHS 136:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCHS 137:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCHS 138:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCHS 139:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCHS 140:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCHS 141:	Training loss: 0.384	Validation loss: 0.379
#
# EPOCHS 142:	Training loss: 0.384	Validation loss: 0.378
#
# EPOCHS 143:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCHS 144:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCHS 145:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCHS 146:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCHS 147:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCHS 148:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCHS 149:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCHS 150:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCHS 151:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCHS 152:	Training loss: 0.383	Validation loss: 0.378
#
# EPOCHS 153:	Training loss: 0.383	Validation loss: 0.377
#
# EPOCHS 154:	Training loss: 0.383	Validation loss: 0.377
#
# EPOCHS 155:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCHS 156:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCHS 157:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCHS 158:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCHS 159:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCHS 160:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCHS 161:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCHS 162:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCHS 163:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCHS 164:	Training loss: 0.382	Validation loss: 0.377
#
# EPOCHS 165:	Training loss: 0.382	Validation loss: 0.376
#
# EPOCHS 166:	Training loss: 0.382	Validation loss: 0.376
#
# EPOCHS 167:	Training loss: 0.382	Validation loss: 0.376
#
# EPOCHS 168:	Training loss: 0.382	Validation loss: 0.376
#
# EPOCHS 169:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCHS 170:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCHS 171:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCHS 172:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCHS 173:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCHS 174:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCHS 175:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCHS 176:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCHS 177:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCHS 178:	Training loss: 0.381	Validation loss: 0.376
#
# EPOCHS 179:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCHS 180:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCHS 181:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCHS 182:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCHS 183:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCHS 184:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCHS 185:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCHS 186:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCHS 187:	Training loss: 0.381	Validation loss: 0.375
#
# EPOCHS 188:	Training loss: 0.380	Validation loss: 0.375
#
# EPOCHS 189:	Training loss: 0.380	Validation loss: 0.375
#
# EPOCHS 190:	Training loss: 0.380	Validation loss: 0.375
#
# EPOCHS 191:	Training loss: 0.380	Validation loss: 0.375
#
# EPOCHS 192:	Training loss: 0.380	Validation loss: 0.375
#
# EPOCHS 193:	Training loss: 0.380	Validation loss: 0.375
#
# EPOCHS 194:	Training loss: 0.380	Validation loss: 0.375
#
# EPOCHS 195:	Training loss: 0.380	Validation loss: 0.375
#
# EPOCHS 196:	Training loss: 0.380	Validation loss: 0.375
#
# EPOCHS 197:	Training loss: 0.380	Validation loss: 0.375
#
# EPOCHS 198:	Training loss: 0.380	Validation loss: 0.374
#
# EPOCHS 199:	Training loss: 0.380	Validation loss: 0.374
#
# EPOCHS 200:	Training loss: 0.380	Validation loss: 0.374

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, 'orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %%
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy(X_test, y_test, theta)
print('Evaluation on validation and test set')
print(f'Accuracy: {val_set_acc}')
print(f'Accuracy: {test_set_acc}')
# Out:
# Evaluation on validation and test set
# Accuracy: 0.821969696969697
# Accuracy: 0.8434343434343434
